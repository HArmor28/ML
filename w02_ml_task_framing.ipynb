# %% [markdown]
# <a href="https://colab.research.google.com/github/HArmor28/ML/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HArmor28/ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# My lane (3) discovers groups of pages with similar measurable characteristics which is a clustering task. Clustering fits because no predefined labels exist to sort the data and must be discovered from observing the data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Since this is a clustering task, there is no observed outcome or predefined label. The output is a cluster assignment pertaining to each page. While archetype names are added, they are interpretations, not true labels. The cluster assignments are based off structured measurements such as CTR, impressions, average position, engagement, content age, and word count.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# I will use a silhouette score as a main metric. It measures geometric separaiton rather than effectivness. I will treat a score near 1 as compact and clearly separated clusters, near 0 as overlapping clusters, and below 0 as many pages being assigned poorly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row represents one pseudonymized content page. Each row contains structured performance and content measurements that can be used to compare pages and discover archetypes. content_id ids the page but will not be used in clustering.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

data_url = (
    "https://raw.githubusercontent.com/"
    "HArmor28/ML/main/data/raw/content_refresh_anonymized.csv"
)

df = pd.read_csv(data_url)

lane3_columns = [
    "content_id",
    "impressions_90d",
    "clicks_90d",
    "ctr",
    "avg_position",
    "sessions_90d",
    "engagement_rate",
    "content_age_days",
    "word_count",
]

lane3_df = df[lane3_columns].copy()

print("Rows and columns:", lane3_df.shape)
print("Duplicate content IDs:", lane3_df["content_id"].duplicated().sum())
lane3_df.head()
# Out:
# Rows and columns: (30000, 9)
# Duplicate content IDs: 0
#              content_id  impressions_90d  clicks_90d   ctr  avg_position  \
# 0  content_304f48230142             3803          29  0.76          10.6
# 1  content_a1fb4e703a9e            15320           7  0.05          20.3
# 2  content_9aa793d4d895            12581          11  0.09          36.5
# 3  content_331d6c4de07b            11751          58  0.49           6.2
# 4  content_d99b7a2d90ca            19140          24  0.13          44.0
#
#    sessions_90d  engagement_rate  content_age_days  word_count
# 0            17             5.88               187      3221.0
# 1             9             0.00               445      2481.0
# 2            11             0.00               141      3515.0
# 3            78             1.28               463         NaN
# 4           145             0.00               263      2803.0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule requires defined archetypes in advance, while clusteirng can discover combinations. Content performance depends on interacting measuremetns, therefore similar pages may not share one obvious cutoff. Clustering allows us to examine these measurements together and identify recurring structured patterns. The code below shows why one threshold is unlikley to describe every archetype and cleaning/scaling will be needed before clustering.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane3_df.drop(columns="content_id").describe().T[
    ["mean", "std", "min", "max"]
]
# Out:
#                          mean           std   min       max
# impressions_90d   5200.366300  16838.019547   1.0  517715.0
# clicks_90d          16.097333     75.076958   0.0    4178.0
# ctr                  0.510733      3.279162   0.0     100.0
# avg_position        16.342380     15.216790   0.0     245.0
# sessions_90d        37.066633    107.069131   1.0    4345.0
# engagement_rate      2.534520      8.310096   0.0     100.0
# content_age_days   256.167800    132.707930  90.0     564.0
# word_count        3107.760325   1452.382598   8.0    9546.0

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
