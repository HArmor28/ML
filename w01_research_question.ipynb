# %% [markdown]
# <a href="https://colab.research.google.com/github/HArmor28/ML/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HArmor28/ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose the Structured Content and Archetype Clustering lane. This takes a look at how pages that behave similary perfrom and allows for efficient decision making regarding what actions to take with the page. This used methods such as K-means or other clustering methods rather than semantic organization.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# My work aims to improve how decisions related to optimization are made. For example, clustering pages by similar performance characteristics, teams can act on these insights to prioritize content uploads, develop targeted content strategies, and allocate costs. A wrong recommendation could result in wasted resources, missed opportunitites, and reduced ROI as well as overall ineffeciency.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

try:
    df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
    print(f"Loaded the starter dataset with {len(df):,} entries and {df.shape[1]} features.\n")

    # --- Numbers relevant to 'Structured Content and Archetype Clustering' lane ---

    # 1. Total number of records (content items)
    print(f"1. Total content items: {len(df):,}")

    # 2. Number of unique clients
    print(f"2. Number of unique clients: {df['client_id'].nunique():,}")

    # 3. Average 90-day impressions (as a proxy for content visibility/demand)
    print(f"3. Average 90-day impressions per content item: {df['impressions_90d'].mean():,.2f}")

except FileNotFoundError:
    print("Error: 'data/raw/content_refresh_anonymized.csv' not found. Please ensure the file is in the correct path.")
except KeyError as e:
    print(f"Error: Missing expected column in the dataset: {e}. Please check the CSV file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: 'data/raw/content_refresh_anonymized.csv' not found. Please ensure the file is in the correct path.

# %% [markdown]
# ### Troubleshooting `FileNotFoundError` for `data/raw/content_refresh_anonymized.csv`
#
# The error indicates that the file `data/raw/content_refresh_anonymized.csv` could not be found. This file is expected to be part of your starter repository. In a Colab environment, you typically need to clone your repository to make its files accessible.
#
# Run the following cell to clone your repository (if you haven't already) and then list the contents of the `data/raw` directory to confirm the file's presence. **Remember to replace `YOUR_REPO_URL` with the actual URL of your internship repository.**

# %%
# Replace 'YOUR_REPO_URL' with the actual URL of your repository
# For example: 'https://github.com/HArmor28/ML.git'
repo_url = "YOUR_REPO_URL"

# Clone the repository if it doesn't already exist
# The ! operator executes shell commands
# !git clone $repo_url

# Navigate into the cloned repository directory
# This assumes your repository name is 'ML' if the URL is '.../ML.git'
# Adjust 'ML' if your repo has a different name
repo_name = repo_url.split('/')[-1].replace('.git', '')
# %cd $repo_name

# List contents of the data/raw directory to verify the file
# !ls data/raw/

# After successfully cloning and verifying the file, you might need to re-run
# the cell above (uJ-OLG-94GCB) to load the dataframe correctly.
# Out:
# fatal: repository 'YOUR_REPO_URL' does not exist
# [Errno 2] No such file or directory: 'YOUR_REPO_URL'
# /content
# ls: cannot access 'data/raw/': No such file or directory

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
